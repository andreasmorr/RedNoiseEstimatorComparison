# %%
import SampleGeneration
import EstimationMethods
import WindowEstimation
import MethodComparisons
import importlib
importlib.reload(SampleGeneration)
importlib.reload(EstimationMethods)
importlib.reload(WindowEstimation)
importlib.reload(MethodComparisons)
import matplotlib.pyplot as plt
import numpy as np

# %%
ns=[100,150,200,300,400,500,600,700,800,900,1000,1100]
lambda_=0.3
theta_=2
kappa_=1
sample_size=10000
oversampling=100

# %%
results_against_n = []
for n in ns:
    print(n)
    results_n = MethodComparisons.estimator_distributions(sample_size=sample_size, n=n, oversampling=oversampling, lambda_=lambda_, theta_=theta_, kappa_=kappa_, initial=[1,1,1], relevant_lags = 3)
    results_against_n.append(results_n)
# Out:
# 100
# Start time: 2023-03-11 00:41:41; Progress: 0%
# End time: 2023-03-11 00:45:53; Progress: 0%
# 150
# Start time: 2023-03-11 00:45:26; Progress: 0%
# End time: 2023-03-11 00:50:47; Progress: 0%
# 200
# Start time: 2023-03-11 00:50:29; Progress: 0%
# End time: 2023-03-11 00:56:39; Progress: 0%
# 300
# Start time: 2023-03-11 00:56:46; Progress: 0%
# End time: 2023-03-11 01:05:40; Progress: 0%
# 400
# Start time: 2023-03-11 01:05:32; Progress: 0%
# End time: 2023-03-11 01:17:32; Progress: 0%
# 500
# Start time: 2023-03-11 01:16:47; Progress: 0%
# End time: 2023-03-11 01:30:30; Progress: 0%
# 600
# Start time: 2023-03-11 01:30:35; Progress: 0%
# End time: 2023-03-11 01:47:27; Progress: 0%
# 700
# Start time: 2023-03-11 01:46:54; Progress: 0%
# End time: 2023-03-11 02:05:15; Progress: 0%
# 800
# Start time: 2023-03-11 02:05:45; Progress: 0%
# End time: 2023-03-11 02:27:45; Progress: 0%
# 900
# Start time: 2023-03-11 02:27:08; Progress: 0%
# End time: 2023-03-11 02:50:40; Progress: 0%
# 1000
# Start time: 2023-03-11 02:51:01; Progress: 0%
# End time: 2023-03-11 03:17:24; Progress: 0%
# 1100
# Start time: 2023-03-11 03:17:28; Progress: 0%
# End time: 2023-03-11 03:46:31; Progress: 0%

# %%
sigmas_against_n = MethodComparisons.get_sigma_intervals(results_against_n=results_against_n, lambda_=lambda_, theta_=theta_, kappa_=kappa_)

# %%
MethodComparisons.plot_interval_convergence(ns,sigmas_against_n)
# Out:
# [1.08056972]
# [0.43466187]
# [1.29217704]
# [1.36034498]
