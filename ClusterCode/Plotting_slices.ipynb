# %%
import SampleGeneration
import EstimationMethods
import WindowEstimation
import MethodComparisons
import importlib
import tpr_fpr_auc
importlib.reload(SampleGeneration)
importlib.reload(EstimationMethods)
importlib.reload(WindowEstimation)
importlib.reload(MethodComparisons)
importlib.reload(tpr_fpr_auc)
import matplotlib.pyplot as plt
import numpy as np

# %%
MethodComparisons.plot_slices(1,1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 MethodComparisons.plot_slices(1,1)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/PhD Studium/Eigene Papers/EstimationLandscape/RedNoiseEstimatorComparison/ClusterCode/MethodComparisons.py:478, in plot_slices(window_index, obslen_index)
#     476 axs[1].set_xlabel("Length of the time series",fontsize=12)
#     477 for method in range(5):
# --> 478     axs[1].plot(np.round(dfs[method].index,0).astype(int),dfs[method].iloc[:,obslen_index],c=cols[method])
#     479 axs[1].legend(["Variance", "AC(1)", "ACS", "PSD"],loc="upper left")
#     480 axs[1].text(-0.15, 0.97, labels[1], transform=axs[1].transAxes,
#     481                         fontsize=20, verticalalignment='top', bbox=props)
#
# IndexError: list index out of range

# %%
MethodComparisons.plot_heat_auc()
