# %%
import SampleGeneration
import EstimationMethods
import WindowEstimation
import MethodComparisons
import importlib
import plot_slices
import plot_heat
import tpr_fpr_auc
importlib.reload(SampleGeneration)
importlib.reload(EstimationMethods)
importlib.reload(WindowEstimation)
importlib.reload(MethodComparisons)
importlib.reload(plot_slices)
importlib.reload(plot_heat)
importlib.reload(tpr_fpr_auc)
import matplotlib.pyplot as plt
import numpy as np

# %%
plot_slices.plot_slices(1,1)

# %%
plot_heat.plot_heat_auc()

# %%
plot_heat.plot_heat_auc_slides()

# %%
plot_heat.plot_heat_example_slides()
